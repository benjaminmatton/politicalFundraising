# %%
import pandas as pd
historical_senate = pd.read_csv('beastModeData/senate_polls_historical.csv')
historical_senate
# Out:
#       poll_id  pollster_id               pollster sponsor_ids       sponsors  \
# 0       81762         1250        Trafalgar Group         NaN            NaN
# 1       81762         1250        Trafalgar Group         NaN            NaN
# 2       81760         1515      Data for Progress         NaN            NaN
# 3       81760         1515      Data for Progress         NaN            NaN
# 4       81759          235       InsiderAdvantage         195  Fox 5 Atlanta
# ...       ...          ...                    ...         ...            ...
# 6653    53946          290  MassINC Polling Group          83           WBUR
# 6654    52630          610           Texas Lyceum         NaN            NaN
# 6655    52630          610           Texas Lyceum         NaN            NaN
# 6656    52643          988         Harper Polling         NaN            NaN
# 6657    52643          988         Harper Polling         NaN            NaN
#
#                display_name  pollster_rating_id   pollster_rating_name  \
# 0           Trafalgar Group                 338        Trafalgar Group
# 1           Trafalgar Group                 338        Trafalgar Group
# 2         Data for Progress                 522      Data for Progress
# 3         Data for Progress                 522      Data for Progress
# 4          InsiderAdvantage                 243       InsiderAdvantage
# ...                     ...                 ...                    ...
# 6653  MassINC Polling Group                 198  MassINC Polling Group
# 6654           Texas Lyceum                 431           Texas Lyceum
# 6655           Texas Lyceum                 431           Texas Lyceum
# 6656         Harper Polling                 132         Harper Polling
# 6657         Harper Polling                 132         Harper Polling
#
#       numeric_grade  pollscore  ... election_date    stage nationwide_batch  \
# 0               0.7        0.6  ...       12/6/22   runoff            False
# 1               0.7        0.6  ...       12/6/22   runoff            False
# 2               2.6       -1.2  ...       12/6/22   runoff            False
# 3               2.6       -1.2  ...       12/6/22   runoff            False
# 4               2.0       -0.3  ...       12/6/22   runoff            False
# ...             ...        ...  ...           ...      ...              ...
# 6653            2.8       -0.8  ...       11/6/18  general            False
# 6654            NaN        NaN  ...       11/6/18  general            False
# 6655            NaN        NaN  ...       11/6/18  general            False
# 6656            NaN       -0.3  ...       11/6/18  general            False
# 6657            NaN       -0.3  ...       11/6/18  general            False
#
#      ranked_choice_reallocated ranked_choice_round  party    answer  \
# 0                        False                 NaN    DEM   Warnock
# 1                        False                 NaN    REP    Walker
# 2                        False                 NaN    DEM   Warnock
# 3                        False                 NaN    REP    Walker
# 4                        False                 NaN    DEM   Warnock
# ...                        ...                 ...    ...       ...
# 6653                     False                 NaN    REP     Diehl
# 6654                     False                 NaN    DEM  O'Rourke
# 6655                     False                 NaN    REP      Cruz
# 6656                     False                 NaN    DEM   Manchin
# 6657                     False                 NaN    REP  Morrisey
#
#      candidate_id          candidate_name   pct
# 0           19086         Raphael Warnock  51.1
# 1           19088  Herschel Junior Walker  47.4
# 2           19086         Raphael Warnock  51.0
# 3           19088  Herschel Junior Walker  49.0
# 4           19086         Raphael Warnock  50.5
# ...           ...                     ...   ...
# 6653        12481             Geoff Diehl  29.0
# 6654        11125           Beto O'Rourke  30.0
# 6655        11126                Ted Cruz  30.0
# 6656        11132        Joe Manchin, III  57.0
# 6657        11133        Patrick Morrisey  35.0
#
# [6658 rows x 51 columns]

# %%
import re

wanted_variables = ['candidate_name','party','cycle','office_type','race_id', 'state','pollscore', 'pct','created_at']
poll = historical_senate[wanted_variables]

poll.loc[:, 'created_at'] = pd.to_datetime(poll['created_at'], format="%m/%d/%y %H:%M")
poll = poll.sort_values(by='created_at', ascending=False)

# Drop duplicates based on 'CAND_ID', keeping the latest row
poll = poll.drop_duplicates(subset=['candidate_name'], keep='first')
poll = poll.reset_index(drop=True).drop('created_at', axis=1)

# Normalization Function
def normalize_name(name):
    # Convert to lowercase
    name = name.lower()
    # Strip whitespace
    name = name.strip()
    # Remove special characters (optional)
    name = re.sub(r'[^a-zA-Z\s]', '', name)  # Removes punctuation and special characters
    return name

poll.loc[:, 'candidate_name'] = poll['candidate_name'].apply(normalize_name)

poll
# Out:
#              candidate_name party  cycle  office_type  race_id          state  \
# 0    herschel junior walker   REP   2022  U.S. Senate     8925        Georgia
# 1    catherine cortez masto   DEM   2022  U.S. Senate     8937         Nevada
# 2           raphael warnock   DEM   2022  U.S. Senate     8925        Georgia
# 3                 mehmet oz   REP   2022  U.S. Senate     8945   Pennsylvania
# 4            john fetterman   DEM   2022  U.S. Senate     8945   Pennsylvania
# ..                      ...   ...    ...          ...      ...            ...
# 432           jason shelton   DEM   2018  U.S. Senate      130    Mississippi
# 433              joe arpaio   REP   2018  U.S. Senate       96        Arizona
# 434         don blankenship   IND   2018  U.S. Senate      126  West Virginia
# 435             aubrey dunn   LIB   2018  U.S. Senate      114     New Mexico
# 436        jonathan jenkins   IND   2018  U.S. Senate      121          Texas
#
#      pollscore   pct
# 0         -0.8  46.5
# 1          0.6  45.4
# 2          0.7  59.0
# 3          0.7  47.0
# 4          0.7  53.0
# ..         ...   ...
# 432        0.0   6.2
# 433        0.2  35.0
# 434        0.0  11.0
# 435        0.4   5.3
# 436       -0.1   6.0
#
# [437 rows x 8 columns]

# %%
# Group by the 'cycle' column and create a dictionary of DataFrames
cycle_dataframes = {cycle: group for cycle, group in poll.groupby('cycle')}

# %%
# Group candidates by race_id for each cycle DataFrame
grouped_candidates = {}
for cycle, group in cycle_dataframes.items():
    grouped_candidates[cycle] = group.groupby('race_id').agg({
        'candidate_name': list,  # Aggregate names into lists
        'party': 'first',        # Take the first party
        'cycle': 'first',        # Take the first cycle (same for all in the group)
        'office_type': 'first',  # Take the first office_type (same for all in the group)
        'state': 'first',
        'pollscore': list,
        'pct': list
    })
# Build separate DataFrames for each cycle
dataframes_by_cycle = {}
for cycle, grouped in grouped_candidates.items():
    dataframes_by_cycle[cycle] = grouped

# %%
dataframes_by_cycle[2022]
# Out:
#                                             candidate_name party  cycle  \
# race_id
# 8917             [will boyd, katie britt, john sophocleus]   DEM   2022
# 8918     [kelly c tshibaka, lisa murkowski, buzz a kell...   REP   2022
# 8919     [marc victor, blake masters, mark kelly, mark ...   LIB   2022
# 8920          [kenneth cates, natalie james, john boozman]   LIB   2022
# 8921                                        [alex padilla]   DEM   2022
# 8922     [joe odea, michael bennet, brian peotter, fran...   REP   2022
# 8923     [leora r levy, richard blumenthal, themis klar...   REP   2022
# 8924     [val demings, marco rubio, dennis misigoy, ste...   DEM   2022
# 8925     [herschel junior walker, raphael warnock, chas...   REP   2022
# 8928          [tammy duckworth, kathy salvi, bill redpath]   DEM   2022
# 8929         [thomas mcdermott, todd young, james sceniak]   DEM   2022
# 8930     [michael franken, chuck grassley, abby finkena...   DEM   2022
# 8931         [mark r holland, jerry moran, david c graham]   DEM   2022
# 8932                           [rand paul, charles booker]   REP   2022
# 8933     [gary chambers, syrita steib, john kennedy, lu...   DEM   2022
# 8935        [chris chaffee, chris van hollen, larry hogan]   REP   2022
# 8936     [trudy busch valentine, eric schmitt, jonathan...   DEM   2022
# 8937     [catherine cortez masto, neil scott, adam paul...   DEM   2022
# 8938     [jeremy kauffman, maggie hassan, donald c bold...   LIB   2022
# 8939           [charles e schumer, joe pinion, diane sare]   DEM   2022
# 8940     [matthew hoh, shannon w bray, ted budd, cheri ...   GRE   2022
# 8942     [jd vance, tim ryan, josh mandel, jane timken,...   REP   2022
# 8943     [madison horn, james lankford, kenneth d blevi...   DEM   2022
# 8944     [dan pulju, jo rae perkins, ron wyden, chris h...    PG   2022
# 8945     [mehmet oz, john fetterman, erik gerhardt, ric...   REP   2022
# 8946            [krystle matthews, tim scott, larry adams]   DEM   2022
# 8947        [john r thune, tamara j lesnar, brian l bengs]   REP   2022
# 8948     [evan mcmullin, mike lee, tommy williams, jame...   IND   2022
# 8949     [gerald malloy, peter welch, cris ericson, ker...   REP   2022
# 8950                        [tiffany smiley, patty murray]   REP   2022
# 8951     [ron johnson, mandela barnes, tom nelson, alex...   REP   2022
# 9480                                       [mark p meuser]   REP   2022
# 9482     [markwayne mullin, kendra horn, ray woods, rob...   REP   2022
#
#          office_type           state  \
# race_id
# 8917     U.S. Senate         Alabama
# 8918     U.S. Senate          Alaska
# 8919     U.S. Senate         Arizona
# 8920     U.S. Senate        Arkansas
# 8921     U.S. Senate      California
# 8922     U.S. Senate        Colorado
# 8923     U.S. Senate     Connecticut
# 8924     U.S. Senate         Florida
# 8925     U.S. Senate         Georgia
# 8928     U.S. Senate        Illinois
# 8929     U.S. Senate         Indiana
# 8930     U.S. Senate            Iowa
# 8931     U.S. Senate          Kansas
# 8932     U.S. Senate        Kentucky
# 8933     U.S. Senate       Louisiana
# 8935     U.S. Senate        Maryland
# 8936     U.S. Senate        Missouri
# 8937     U.S. Senate          Nevada
# 8938     U.S. Senate   New Hampshire
# 8939     U.S. Senate        New York
# 8940     U.S. Senate  North Carolina
# 8942     U.S. Senate            Ohio
# 8943     U.S. Senate        Oklahoma
# 8944     U.S. Senate          Oregon
# 8945     U.S. Senate    Pennsylvania
# 8946     U.S. Senate  South Carolina
# 8947     U.S. Senate    South Dakota
# 8948     U.S. Senate            Utah
# 8949     U.S. Senate         Vermont
# 8950     U.S. Senate      Washington
# 8951     U.S. Senate       Wisconsin
# 9480     U.S. Senate      California
# 9482     U.S. Senate        Oklahoma
#
#                                                  pollscore  \
# race_id
# 8917                                    [-1.1, -1.1, -1.1]
# 8918     [-0.1, -0.1, -0.1, -0.1, 0.7, 0.7, -0.1, -0.1,...
# 8919     [0.1, 0.1, 0.1, 0.4, 0.4, -1.2, -0.4, -0.4, -0...
# 8920                                    [-0.4, -0.4, -0.4]
# 8921                                                [-0.5]
# 8922     [0.3, 0.3, -1.2, -1.1, -1.1, -0.5, -0.3, -0.5,...
# 8923                                 [1.8, 1.8, 1.6, -1.1]
# 8924              [-1.2, -1.2, -1.2, -1.0, -1.0, 0.7, 0.4]
# 8925                      [-0.8, 0.7, 0.1, -0.2, 0.0, nan]
# 8928                                    [-0.5, -0.5, -1.1]
# 8929                                     [-0.2, -0.2, nan]
# 8930                                     [-1.2, -1.2, 0.7]
# 8931                                    [-1.1, -1.1, -1.1]
# 8932                                          [-1.1, -1.1]
# 8933                                  [0.0, 0.0, 0.0, 0.0]
# 8935                                      [nan, nan, -0.1]
# 8936     [-0.2, -0.2, 0.6, -1.1, -1.1, -1.3, -1.3, -1.3...
# 8937                      [0.6, 0.6, 0.6, -0.3, -0.3, 0.5]
# 8938     [-1.2, -1.2, -1.2, -1.2, -1.2, -0.3, -0.4, -0....
# 8939                                    [-0.5, -0.5, -1.1]
# 8940            [-1.2, -1.2, -1.2, -1.2, -0.5, -1.1, -1.1]
# 8942                             [0.1, 0.1, 0.4, 0.4, 0.0]
# 8943                                  [1.7, 1.7, 1.7, 1.7]
# 8944                              [-1.2, -1.2, -1.2, -1.2]
# 8945     [0.7, 0.7, 0.1, -0.6, -1.1, -1.1, -1.0, -1.0, ...
# 8946                                     [-0.8, -0.8, 0.7]
# 8947                                    [-1.1, -1.1, -1.1]
# 8948       [-0.4, -0.4, -0.4, -0.4, 0.7, -0.4, -0.4, -0.4]
# 8949     [-1.2, -1.2, -0.3, -0.3, -0.3, -0.3, -0.3, -0....
# 8950                                            [0.7, 0.7]
# 8951                        [-1.2, -1.2, -1.1, -1.1, -1.1]
# 9480                                                [-0.5]
# 9482                                  [1.7, 1.7, 1.7, 1.7]
#
#                                                        pct
# race_id
# 8917                                     [27.5, 57.1, 6.3]
# 8918     [44.5, 55.5, 3.9, 16.4, 16.0, 4.0, 4.6, 20.0, ...
# 8919     [2.0, 47.0, 50.0, 40.0, 34.0, 47.0, 37.0, 36.0...
# 8920                                     [4.6, 25.8, 54.6]
# 8921                                                [53.0]
# 8922     [43.0, 51.0, 2.0, 0.5, 1.2, 37.0, 40.1, 35.0, ...
# 8923                              [26.0, 51.0, 34.0, 35.1]
# 8924                [43.0, 55.0, 1.0, 1.4, 0.6, 5.0, 37.0]
# 8925                   [46.5, 59.0, 3.0, 40.7, 44.0, 45.2]
# 8928                                     [58.0, 40.0, 2.1]
# 8929                                     [38.0, 49.0, 6.0]
# 8930                                    [41.0, 53.0, 36.0]
# 8931                                     [32.6, 54.2, 3.0]
# 8932                                          [55.0, 39.0]
# 8933                                [8.0, 6.0, 53.0, 16.0]
# 8935                                    [33.0, 56.0, 49.0]
# 8936     [40.0, 55.0, 2.1, 1.4, 10.0, 34.0, 31.0, 26.0,...
# 8937                     [45.4, 1.4, 50.3, 2.0, 0.0, 24.0]
# 8938     [2.0, 50.0, 47.0, 46.0, 45.0, 40.0, 45.0, 46.0...
# 8939                                     [59.0, 39.0, 1.3]
# 8940              [1.0, 2.0, 51.0, 45.0, 45.0, 47.1, 44.2]
# 8942                        [52.0, 45.0, 41.0, 36.0, 40.0]
# 8943                                [36.0, 56.0, 1.0, 2.0]
# 8944                                [1.0, 42.0, 56.0, 1.0]
# 8945     [47.0, 53.0, 3.0, 1.0, 0.2, 4.0, 0.2, 0.6, 42....
# 8946                                     [37.0, 54.0, 5.0]
# 8947                                     [58.0, 5.0, 27.0]
# 8948        [36.0, 51.0, 1.0, 3.0, 13.0, 31.0, 24.0, 11.0]
# 8949     [32.0, 63.0, 1.0, 0.0, 1.0, 0.0, 27.0, 38.0, 4...
# 8950                                          [47.4, 47.0]
# 8951                        [53.0, 47.0, 44.0, 42.0, 45.0]
# 9480                                                [37.0]
# 9482                                [53.0, 41.0, 2.0, 1.0]

# %%
# Read the file into a DataFrame, specifying the delimiter as '|'
df18 = pd.read_csv('beastModeData/fecData/weball18.txt', delimiter='|', header=None)
df20 = pd.read_csv('beastModeData/fecData/weball20.txt', delimiter='|', header=None)
df22 = pd.read_csv('beastModeData/fecData/weball22.txt', delimiter='|', header=None)

# %%
df18.columns = [
    'CAND_ID', 'CAND_NAME', 'CAND_ICI', 'PTY_CD', 'CAND_PTY_AFFILIATION',
    'TTL_RECEIPTS', 'TRANS_FROM_AUTH', 'TTL_DISB', 'TRANS_TO_AUTH',
    'COH_BOP', 'cash_on_hand', 'CAND_CONTRIB', 'CAND_LOANS', 'OTHER_LOANS',
    'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY', 'TTL_INDIV_CONTRIB',
    'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT', 'SPEC_ELECTION', 'PRIM_ELECTION',
    'RUN_ELECTION', 'GEN_ELECTION', 'GEN_ELECTION_PRECENT', 'OTHER_POL_CMTE_CONTRIB',
    'POL_PTY_CONTRIB', 'CVG_END_DT', 'INDIV_REFUNDS', 'CMTE_REFUNDS'
]
# Normalization Function to rearrange names
def normalize_full_name(name):
    # Remove special characters and extra spaces
    name = re.sub(r'[^a-zA-Z\s,]', '', name)  # Remove any unwanted characters
    name = name.strip()
    
    # Split by comma and then by spaces
    parts = name.split(',')
    
    if len(parts) == 2:
        last_name = parts[0].strip()  # Get the last name
        first_middle = parts[1].strip()  # Get the first and middle names
        
        # Combine them in the desired order
        normalized_name = f"{first_middle} {last_name}"  # 'first middle last'
    else:
        normalized_name = name  # Fallback if the format is unexpected
    
    return normalized_name.lower()



# Apply the conversion function to df1
df18['CAND_NAME'] = df18['CAND_NAME'].apply(normalize_full_name)
df18
# Out:
#         CAND_ID            CAND_NAME CAND_ICI  PTY_CD CAND_PTY_AFFILIATION  \
# 0     H8AK00132        dimitri shein        C       1                  DEM
# 1     H6AK00045       donald e young        I       2                  REP
# 2     H8AK00116   gabrielle r ledoux        C       2                  REP
# 3     H8AK01031   thomas john nelson        C       2                  REP
# 4     H8AK00140         alyse galvin        C       3                  IND
# ...         ...                  ...      ...     ...                  ...
# 3682  S4WY00097      charles e hardy        C       2                  REP
# 3683  S4WY00147  bryan edward miller        C       2                  REP
# 3684  S6WY00068      john a barrasso        I       2                  REP
# 3685  S6WY00126       michael b enzi        I       2                  REP
# 3686  S8WY00197         david dodson        C       2                  REP
#
#       TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  TRANS_TO_AUTH     COH_BOP  \
# 0        209916.04             0.00   209574.16            0.0        0.00
# 1       1234680.31             0.00  1387687.05            0.0   269726.86
# 2             0.00             0.00   540033.00            0.0      479.00
# 3          9288.48             0.00     8821.97            0.0        0.00
# 4       1949643.68           154.70  1943398.59            0.0        0.00
# ...            ...              ...         ...            ...         ...
# 3682       9058.00             0.00     8891.00            0.0        0.00
# 3683          0.00             0.00        0.00            0.0        0.00
# 3684    5667279.48        256656.69  4458971.93            0.0  2749487.00
# 3685     232162.96             0.00   332047.38            0.0   580995.00
# 3686    2101897.77             0.00  2101897.48            0.0        0.00
#
#       ...  SPEC_ELECTION  PRIM_ELECTION  RUN_ELECTION  GEN_ELECTION  \
# 0     ...            NaN            NaN           NaN           NaN
# 1     ...            NaN            NaN           NaN           NaN
# 2     ...            NaN            NaN           NaN           NaN
# 3     ...            NaN            NaN           NaN           NaN
# 4     ...            NaN            NaN           NaN           NaN
# ...   ...            ...            ...           ...           ...
# 3682  ...            NaN            NaN           NaN           NaN
# 3683  ...            NaN            NaN           NaN           NaN
# 3684  ...            NaN            NaN           NaN           NaN
# 3685  ...            NaN            NaN           NaN           NaN
# 3686  ...            NaN            NaN           NaN           NaN
#
#       GEN_ELECTION_PRECENT  OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  \
# 0                      NaN                    0.00              0.0
# 1                      NaN               559861.90              0.0
# 2                      NaN                    0.00              0.0
# 3                      NaN                    0.00              0.0
# 4                      NaN               114833.97              0.0
# ...                    ...                     ...              ...
# 3682                   NaN                    0.00              0.0
# 3683                   NaN                    0.00              0.0
# 3684                   NaN              2555865.00              0.0
# 3685                   NaN               190500.00              0.0
# 3686                   NaN                    0.00              0.0
#
#       CVG_END_DT INDIV_REFUNDS  CMTE_REFUNDS
# 0     12/31/2018          0.00           0.0
# 1     12/31/2018       2700.00         500.0
# 2     09/30/2018          0.00           0.0
# 3     12/31/2018        600.00           0.0
# 4     12/31/2018       8166.36           0.0
# ...          ...           ...           ...
# 3682  12/31/2018          0.00           0.0
# 3683  12/31/2018          0.00           0.0
# 3684  12/31/2018      55404.00       47500.0
# 3685  12/31/2018          0.00           0.0
# 3686  12/31/2018      43302.00           0.0
#
# [3687 rows x 30 columns]

# %%
duplicate_counts = df18['CAND_NAME'].value_counts()
duplicates = duplicate_counts[duplicate_counts > 1]
total_duplicates = duplicates.sum()
duplicates
# Out:
# CAND_NAME
# roque rocky de la fuente    4
# james courage singer        2
# steve williams              2
# loretta sanchez             2
# shak hill                   2
#                            ..
# robert marshall             2
# james veltmeyer             2
# steven d welch              2
# danny tarkanian             2
# annette teijeiro            2
# Name: count, Length: 68, dtype: int64

# %%
matching_candidates = df18['CAND_NAME'].isin(poll['candidate_name'])
sum(matching_candidates)

# %%
df20.columns = [
    'CAND_ID', 'CAND_NAME', 'CAND_ICI', 'PTY_CD', 'CAND_PTY_AFFILIATION',
    'TTL_RECEIPTS', 'TRANS_FROM_AUTH', 'TTL_DISB', 'TRANS_TO_AUTH',
    'COH_BOP', 'cash_on_hand', 'CAND_CONTRIB', 'CAND_LOANS', 'OTHER_LOANS',
    'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY', 'TTL_INDIV_CONTRIB',
    'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT', 'SPEC_ELECTION', 'PRIM_ELECTION',
    'RUN_ELECTION', 'GEN_ELECTION', 'GEN_ELECTION_PRECENT', 'OTHER_POL_CMTE_CONTRIB',
    'POL_PTY_CONTRIB', 'CVG_END_DT', 'INDIV_REFUNDS', 'CMTE_REFUNDS'
]

# Apply the conversion function to df1
df20['CAND_NAME'] = df20['CAND_NAME'].apply(normalize_full_name)
df20

# %%
matching_candidates = df20['CAND_NAME'].isin(poll['candidate_name'])
sum(matching_candidates)

# %%
df22.columns = [
    'CAND_ID', 'CAND_NAME', 'CAND_ICI', 'PTY_CD', 'CAND_PTY_AFFILIATION',
    'TTL_RECEIPTS', 'TRANS_FROM_AUTH', 'TTL_DISB', 'TRANS_TO_AUTH',
    'COH_BOP', 'cash_on_hand', 'CAND_CONTRIB', 'CAND_LOANS', 'OTHER_LOANS',
    'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY', 'TTL_INDIV_CONTRIB',
    'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT', 'SPEC_ELECTION', 'PRIM_ELECTION',
    'RUN_ELECTION', 'GEN_ELECTION', 'GEN_ELECTION_PRECENT', 'OTHER_POL_CMTE_CONTRIB',
    'POL_PTY_CONTRIB', 'CVG_END_DT', 'INDIV_REFUNDS', 'CMTE_REFUNDS'
]

# Apply the conversion function to df1
df22['CAND_NAME'] = df22['CAND_NAME'].apply(normalize_full_name)
df22

# %%
matching_candidates = df22['CAND_NAME'].isin(poll['candidate_name'])
sum(matching_candidates)
