# %%
import pandas as pd
historical_house = pd.read_csv('beastModeData/house_polls_historical.csv')
historical_house
# Out:
#       poll_id  pollster_id          pollster sponsor_ids  \
# 0       81569          525  U. New Hampshire         NaN
# 1       81569          525  U. New Hampshire         NaN
# 2       81569          525  U. New Hampshire         NaN
# 3       81569          525  U. New Hampshire         NaN
# 4       81570          525  U. New Hampshire         NaN
# ...       ...          ...               ...         ...
# 3574    53605          383               PPP         971
# 3575    52675          495  Tulchin Research         NaN
# 3576    52675          495  Tulchin Research         NaN
# 3577    52747          603    Strategies 360         NaN
# 3578    52747          603    Strategies 360         NaN
#
#                   sponsors                               display_name  \
# 0                      NaN  University of New Hampshire Survey Center
# 1                      NaN  University of New Hampshire Survey Center
# ...

# %%
# Convert the election_date column to datetime format
historical_house['election_date'] = pd.to_datetime(historical_house['election_date'], format='%m/%d/%y')

# Find the latest date
latest_date = historical_house['election_date'].min()

print("Latest Election Date:", latest_date)
# Out:
# Latest Election Date: 2018-03-13 00:00:00

# %%
#pip install pytrends
# from pytrends.request import TrendReq

# # Initialize the pytrends request
# pytrends = TrendReq()

# # Get Google Trends data for a specific term
# pytrends.build_payload(['Joe Biden'], cat=0, timeframe='today 12-m', geo='', gprop='')

# # Retrieve interest over time
# data = pytrends.interest_over_time()
# print(data)
